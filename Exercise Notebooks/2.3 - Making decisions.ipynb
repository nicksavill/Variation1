# %% [markdown]
# ### Exercise 2.3.1
#
# The following code has an error. Correct the code to make it work.
#
# ```python
# x = 10
# if x < 20:
# print(f'{x} is less than 20')
# ```

# %% [markdown]
# > The `print()` statement below the condition must be indented
# ```python
# x = 10
# if x < 20:
#     print(f'{x} is less than 20')
# ```

# %%
x = 10
if x < 20:
print(f'{x} is less than 20')

# %% [markdown]
# ### Exercise 2.3.2
#
# The following code has an error. Correct the code to make it work.
#
# ```python
# x = 10
# if x < 20
#     print(f'{x} is less than 20')
# ```

# %% [markdown]
# > The colon is missing after the condition
# ```python
# x = 10
# if x < 20:
#     print(f'{x} is less than 20')
# ```

# %%
x = 10
if x < 20
    print(f'{x} is less than 20')

# %% [markdown]
# ### Exercise 2.3.3
#
# The following code has an error. Correct the code to make it work.
#
# ```python
# x = 10
# if x < 20:
#     print(f'{x} is less than 20')
# else:
# ```

# %% [markdown]
# > The statement below `else:` is missing
# ```python
# x = 10
# if x < 20:
#     print(f'{x} is less than 20')
# else:
#     print(f'{x} is equal to or more than 20')
# ```

# %%
x = 10
if x < 20:
    print(f'{x} is less than 20')
else:

# %% [markdown]
# ### Exercise 2.3.4
#
# The following code has an error. Correct the code to make it work.
#
# ```python
# x = 10
# if x = 20:
#     print(f'{x} equals 20')
# else:
#     print(f'{x} does not equal 20')
# ```

# %% [markdown]
# > To test equality in a condition use the double equals sign comparison operator `==` not the single equals sign `=`.
# ```python
# x = 10
# if x == 20:
#     print(f'{x} equals 20')
# else:
#     print(f'{x} does not equal 20')
# ```

# %%
x = 10
if x = 20:
    print(f'{x} equals 20')
else:
    print(f'{x} does not equal 20')

# %% [markdown]
# ### Exercise 2.3.5
#
# The following code has an error. Correct the code to make it work.
#
# ```python
# x = 10
# if x == 20:
#     print(f'{x} equals 20')
# else:
#     print(f'{x} is less than 20')
# elif x > 20:
#     print(f'{x} is greater than 20')
# ```

# %% [markdown]
# > The `else` condition must be the last condition. All `elif` conditions must come before the final `else` condition.
# ```python
# x = 10
# if x == 20:
#     print(f'{x} equals 20')
# elif x > 20:
#     print(f'{x} is greater than 20')
# else:
#     print(f'{x} is less than 20')
# ```

# %%
x = 10
if x == 20:
    print(f'{x} equals 20')
else:
    print(f'{x} is less than 20')
elif x > 20:
    print(f'{x} is greater than 20')

# %% [markdown]
# ### Exercise 2.3.6
#
# 1. Assign the decimals 17.5 and -34.6 to the variables `x` and `y` respectively.
# 2. Test if `x` is greater than `y` and print whether it is or not.
#
# <div class="alert alert-info">
# Your answer should be
#
#     17.5 is greater than -34.6
# </div>
#
# * *Hint: Use `if` ... `else`.*

# %%
x = 17.5
y = -34.6

if x > y:
    print( f'{x} is greater than {y}' )

else:
    print( f'{x} is not greater than {y}' )

# %% [markdown]
# ### Exercise 2.3.7
#
# The normal range of human body temperature is 36.1 $^\circ$C to 37.2 $^\circ$C. It varies by person, age, activity, and time of day.
#
# Complete the code below to print out whether Jane's body temperature is within this normal range or not.
#
# <div class="alert alert-info">
# Your answer should be
#
#     Jane's temperature of 38.5 deg C is outside the normal range
# </div>

# %%
jane_temp = 38.5

if 36.1 < jane_temp < 37.2:
    print(f"Jane's temperature of {jane_temp} deg C is within the normal range")
    
else:
    print(f"Jane's temperature of {jane_temp} deg C is outside the normal range")

# %%
jane_temp = 38.5

# Add your code below here

# %% [markdown]
# ### Exercise 2.3.8
# <br>
# <div>
# <img src="attachment:Certhidea_olivacea.jpg" width='50%' title="Mark Putney CC BY-SA 2.0"/>
# </div>
#
# The average lengths of the beaks of Green and Grey warbler-finch species found on the Galápagos Islands are 6.02 mm and 6.13 mm, respectively.
#
# Complete the code below to print out whether the **absolute difference** in average beak lengths is larger than 0.1 mm.
#
# Note: The difference in average beak lengths can be negative or positive depending on which species' beak length comes first in the calculation of the difference. So you need to check if the difference is less than $-$0.1 mm **or** greater than 0.1 mm.
#
# <div class="alert alert-info">
# Your answer should be
#
#     absolute difference in average beak lengths is greater than 0.1 mm
#
# </div>

# %%
green_beak_length = 6.02
grey_beak_length = 6.13

# difference in average beak lengths
difference = green_beak_length - grey_beak_length

# test if absolute difference is greater than 0.1mm
if difference < -0.1 or difference > 0.1:
    print('absolute difference in average beak lengths is greater than 0.1 mm')
    
else:
    print('absolute difference in average beak lengths is less than 0.1 mm')

# %%
green_beak_length = 6.02
grey_beak_length = 6.13

# difference in average beak lengths
difference = green_beak_length - grey_beak_length

# Add your code below here

# %% [markdown]
# ### Exercise 2.3.9
# <br>
# <div>
# <img src="attachment:Prism.png" title="Marcellus Wallace CC BY 3"/>
# </div>
#
# The wavelength of visible light ranges from 380 to 750 nanometers (nm). While the spectrum is continuous, it is often divided into six colours as shown in this table:
#
#
# Colour | Wavelength (nm)
# :---|:---
# Violet |380 to less than 450
# Blue |450 to less than 495
# Green |495 to less than 570
# Yellow |570 to less than 590
# Orange |590 to less than 620
# Red |620 to 750
#
# 1. In the code below, the variable `wavelength` has been set to 595nm. Complete the code so that it prints the corresponding colour. The code should work for any value of `wavelength`, not just 595nm.
#
# 2. Display an appropriate message if the wavelength entered is outside of the visible spectrum, i.e., less than 380nm and greater than 750nm.
#
# 3. Test your code with different values of `wavelength`.
#
# * *Hint: Use `if` ... `elif` ... `else` with one `elif` for each colour.*
# * *The first couple of conditions are already given, you need to complete the rest.*

# %%
wavelength = 595

if wavelength < 380:
    print('Wavelength is not in the visible spectrum')
elif wavelength < 450:
    print('violet')
elif wavelength < 495:
    print('blue')
elif wavelength < 570:
    print('green')
elif wavelength < 590:
    print('yellow')
elif wavelength < 620:
    print('orange')
elif wavelength < 750:
    print('red')
else:
    print('Wavelength is not in the visible spectrum')

# %%
# Set the wavelength to some value 
wavelength = 595

if wavelength < 380:
    print('Wavelength is not in the visible spectrum')
elif wavelength < 450:
    print('violet')
    
# ADD THE REST OF THE CONDITIONS BELOW HERE

# %% [markdown]
# ## Next Notebook

# %% [markdown]
# [Variables and their types](../Self-study%20Notebooks/2.4%20-%20Variables%20and%20their%20types.ipynb)
